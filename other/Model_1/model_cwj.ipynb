# %% [markdown]
# # date aggregation

# %%
import pandas as pd
import numpy as np
import os

# %%
merge_df = pd.read_csv('merge_df.csv')

# %%
# 날짜만 추출해서 lifelog_date 생성
merge_df['lifelog_date'] = pd.to_datetime(merge_df['timestamp']).dt.date

# 합산 대상 컬럼
sum_cols = ['m_usage_time', 'met_activity', 'distance', 'burned_calories']

# z-score 대상 컬럼
zscore_cols = [
    'wb_rssi', 'ww_rssi', 'avg_heart_rate',
    'avg_latitude', 'avg_longitude', 'avg_altitude',
    'avg_speed', 'avg_light', 'avg_prob_ambience'
]

# 1. z-score 변환: subject_id별로 적용
def zscore(x):
    return (x - x.mean()) / x.std(ddof=0) if x.std(ddof=0) != 0 else 0

merge_df_z = merge_df.copy()
for col in zscore_cols:
    merge_df_z[col] = merge_df.groupby('subject_id')[col].transform(zscore)

# 2. 날짜별 집계: 모든 feature를 sum
agg_dict = {col: 'sum' for col in (sum_cols + zscore_cols)}

daily_df = merge_df_z.groupby(['subject_id', 'lifelog_date']).agg(agg_dict).reset_index()

# %%
daily_df.head(20)
# Out:
#    subject_id lifelog_date  m_usage_time  met_activity     distance  \
# 0        id01   2024-06-26    25418119.0        718.34  2773.860064
# 1        id01   2024-06-27    54102878.0       1091.12  2393.372559
# 2        id01   2024-06-28    45006301.0       1092.40  3219.468748
# 3        id01   2024-06-29    31896684.0       1062.63     0.000000
# 4        id01   2024-06-30    46370978.0       1066.70  2330.986329
# 5        id01   2024-07-01    56707093.0       1117.55  2717.891418
# 6        id01   2024-07-02    41243885.0       1137.79  4915.903809
# 7        id01   2024-07-03    53240886.0       1183.62  4860.677948
# 8        id01   2024-07-04    47954159.0       1088.03   716.051481
# 9        id01   2024-07-05    48280608.0       1141.18  4355.324707
# 10       id01   2024-07-06    41120375.0       1075.15   489.280325
# 11       id01   2024-07-07    36006244.0       1050.76  2387.457116
# 12       id01   2024-07-08    49329121.0       1061.28  2012.965331
# 13       id01   2024-07-09    43933810.0       1077.29  2367.017609
# 14       id01   2024-07-10    51747868.0       1125.11  4715.053467
# 15       id01   2024-07-11           0.0          4.40     0.000000
# 16       id01   2024-07-12    51813981.0       1103.83  2208.510986
# 17       id01   2024-07-13    27020697.0       1042.09     0.000000
# 18       id01   2024-07-14    38073786.0       1077.23  2240.799896
# 19       id01   2024-07-15    51454689.0       1117.27  3443.418703
#
#     burned_calories    wb_rssi    ww_rssi  avg_heart_rate  avg_latitude  \
# 0        189.319059  22.196509  11.625936       -9.093807     -5.686434
# 1        288.990784  10.550762  14.162236      -20.301245    -12.946678
# 2        130.109459   2.067024   1.783410      -86.400161    -13.917672
# 3          0.000000 -33.833208  99.317216     -177.096385    -18.912228
# 4        104.809712 -24.938659  21.952234       81.933425    -18.972328
# 5        121.579084  32.929868 -18.786671      -19.019719    -10.832735
# 6        214.109766  -7.803225 -30.113350       24.195347    -11.269948
# 7        209.960146  12.986787  21.432858       39.684506    -11.792755
# 8         26.360079  14.850587  81.108904       33.718957    -14.431824
# 9        195.379101 -25.296784 -26.178627      -32.401457    -11.557094
# 10        21.760160 -34.224193  -2.623078       84.529494    -34.658320
# 11       114.739676 -16.106127  -0.857957       -2.742587    -18.393955
# 12        86.719900  -1.131785   7.355681      -68.231611    -12.833472
# 13       101.049627 -12.022870 -26.612644      -41.419643    -11.594361
# 14       221.659302   6.643140   6.386047      -33.718076    -13.912896
# 15         0.000000  -0.373562  -0.852803        0.949046     -0.138342
# 16       100.680005  12.821849 -12.776342       32.295726    -12.087554
# 17         0.000000 -46.258088  27.742464       17.469888    -18.876328
# 18        92.130033 -21.496394  34.349680       -4.444050    -18.663700
# 19       157.548337 -12.797439   9.005290      -30.033558    -11.439804
#
#     avg_longitude  avg_altitude  avg_speed  avg_light  avg_prob_ambience
# 0        1.679865    -15.872355  -0.295386  -3.385498        -161.416518
# 1      -11.236354    -18.251124  24.863787  14.365686          49.418628
# 2      -12.849713    -25.682183   8.092535  31.971784          44.033083
# 3      -30.813010     26.933686  -9.107308 -24.660567          49.616197
# 4      -23.006750     60.026278 -17.919958 -15.517770          49.429390
# 5      -11.944249    -19.574743  -8.323015   0.771727          36.780894
# 6      -12.345018    -32.112316  -4.216007 -10.023553          50.077414
# 7       -4.540311    -26.165550 -10.819541  18.001728          48.153042
# 8      -16.218299     22.402143  36.086500  63.212255          47.703869
# 9      -12.148006      7.307549  -0.866701  19.186034          49.666400
# 10     -20.444084     60.029088  64.365452 -14.800919          50.194891
# 11     -23.023257     14.656658 -22.972867 -22.754501          48.774291
# 12     -12.504159    -15.832838 -11.242120 -17.522980          50.224556
# 13     -12.131617    -36.479745  -3.763610 -19.317212          33.419978
# 14      -3.110175     -2.902696  -1.355676  -2.599167          49.556013
# 15      -0.226639      0.246634  -0.214501  -0.234437           0.348782
# 16      -7.831011    -13.521180  12.659805  26.266055          49.436895
# 17     -30.513826      8.760143 -19.837343 -30.525268          48.895325
# 18     -22.720672     23.965474 -23.380888 -10.901843          50.224556
# 19     -12.261584    -17.768591  -5.691643  11.567512          48.675846

# %% [markdown]
# # train, test set merge

# %%
train_df = pd.read_csv('../data/ch2025_metrics_train.csv')
test_df = pd.read_csv('../data/ch2025_submission_sample.csv')

# %%
train_df.shape, test_df.shape, daily_df.shape
# Out:
# ((450, 9), (250, 9), (709, 15))

# %%
# 날짜 컬럼 변환
train_df['lifelog_date'] = pd.to_datetime(train_df['lifelog_date']).dt.date
test_df['lifelog_date'] = pd.to_datetime(test_df['lifelog_date']).dt.date

# 필요한 날짜/ID만 추출
train_key = train_df[['subject_id', 'lifelog_date']].drop_duplicates()
test_key = test_df[['subject_id', 'lifelog_date']].drop_duplicates()

# daily_df 필터링
daily_df_train = pd.merge(daily_df, train_key, on=['subject_id', 'lifelog_date'], how='inner')
daily_df_test = pd.merge(daily_df, test_key, on=['subject_id', 'lifelog_date'], how='inner')

# merge
train_merged = pd.merge(train_df, daily_df_train, on=['subject_id', 'lifelog_date'], how='left')
test_merged = pd.merge(test_df, daily_df_test, on=['subject_id', 'lifelog_date'], how='left')

# %%
train_merged.shape, test_merged.shape
# Out:
# ((450, 22), (250, 22))

# %% [markdown]
# # Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

y_cols = ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']
x_cols = [col for col in train_merged.columns if col not in y_cols + ['subject_id', 'sleep_date', 'lifelog_date']]

test_preds = {}
train_preds = {}

for label in y_cols:
    X_train = train_merged[x_cols].fillna(0)
    y_train = train_merged[label]
    X_test = test_merged[x_cols].fillna(0)

    clf = LogisticRegression(max_iter=100000)
    clf.fit(X_train, y_train)
    test_pred = clf.predict(X_test)
    train_pred = clf.predict(X_train)

    test_preds[label] = test_pred
    train_preds[label] = train_pred

# %% [markdown]
# # Export

# %%
result_df = test_merged[['subject_id', 'sleep_date', 'lifelog_date']].copy()
for label in y_cols:
    result_df[label] = test_preds[label]

# 컬럼 순서 맞추기 (submission_sample 기준)
result_df = result_df[['subject_id', 'sleep_date', 'lifelog_date', 'Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']]

# int type으로 저장
for label in y_cols:
    result_df[label] = result_df[label].astype(int)

result_df.to_csv('result_logistic_cwj', index=False)
